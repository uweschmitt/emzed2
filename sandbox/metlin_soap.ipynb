# %%
message = open("s.xml").read()
import lxml.etree
#tree = lxml.etree.ElementTree(file="s.xml")
tree = lxml.etree.fromstring(message)
#print lxml.etree.tostring(tree, pretty_print=True)

# %%
import requests
r = requests.post("http://metlin.scripps.edu/soap/soapserver.php", data=message)
root = lxml.etree.fromstring(r.text.encode("UTF-8"))
#print root
print lxml.etree.tostring(root, pretty_print=True)
import lxml.objectify
oo = lxml.objectify.fromstring(r.text.encode("UTF-8"))
# Out:
# <SOAP-ENV:Envelope xmlns:SOAP-ENV="http://schemas.xmlsoap.org/soap/envelope/" xmlns:ns1="Eagle" xmlns:SOAP-ENC="http://schemas.xmlsoap.org/soap/encoding/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" SOAP-ENV:encodingStyle="http://schemas.xmlsoap.org/soap/encoding/">
#   <SOAP-ENV:Body>
#     <ns1:MetaboliteSearchResponse>
#       <result SOAP-ENC:arrayType="ns1:singleSearchResult[4]" xsi:type="ns1:multiSearchResult">
#         <item xsi:type="ns1:singleSearchResult"/>
#         <item SOAP-ENC:arrayType="ns1:lineInfo[14]" xsi:type="ns1:singleSearchResult">
#           <item xsi:type="ns1:lineInfo">
#             <molid xsi:type="xsd:string">38608</molid>
#             <mass xsi:type="xsd:string">1024.93976</mass>
#             <name xsi:type="xsd:string">TG(20:0/22:0/22:3(10Z,13Z,16Z))[iso6]</name>
#             <formula xsi:type="xsd:string">C67H124O6</formula>
#           </item>
#           <item xsi:type="ns1:lineInfo">
# ...

# %%
b
# Out:
# <Element {http://schemas.xmlsoap.org/soap/envelope/}Body at 0x55ed2d0>

# %%
    
for e in b.findall('.//item[@{http://www.w3.org/2001/XMLSchema-instance}type="ns1:singleSearchResult"]'):
    print
    for c in e.getchildren():
        print c.mass, c.molid, c.formula, c.name
    print
# Out:
# 1024.93976 38608 C67H124O6 TG(20:0/22:0/22:3(10Z,13Z,16Z))[iso6]
# 1024.93976 38653 C67H124O6 TG(20:3(8Z,11Z,14Z)/22:0/22:0)[iso3]
# 1024.93976 38656 C67H124O6 TG(20:1(11Z)/22:1(13Z)/22:1(13Z))[iso3]
# 1024.93976 38657 C67H124O6 TG(20:2(11Z,14Z)/22:0/22:1(13Z))[iso6]
# 1024.93976 38718 C67H124O6 TG(20:0/22:1(13Z)/22:2(13Z,16Z))[iso6]
# 1024.93976 38719 C67H124O6 TG(20:1(11Z)/22:0/22:2(13Z,16Z))[iso6]
# 1024.93976 38842 C67H124O6 TG(21:0/21:0/22:3(10Z,13Z,16Z))[iso3]
# 1024.845865 39060 C68H112O6 TG(21:0/22:5(7Z,10Z,13Z,16Z,19Z)/22:5(7Z,10Z,13Z,16Z,19Z))[iso3]
# 1024.845865 39066 C68H112O6 TG(21:0/22:4(7Z,10Z,13Z,16Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso6]
# 1024.751963 39108 C69H100O6 TG(22:5(7Z,10Z,13Z,16Z,19Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]
# 1024.751990932 61846 C69H100O6 TG(22:6(4Z,7Z,10Z,13Z,16Z,19Z)/22:5(7Z,10Z,13Z,16Z,19Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))[iso3]
# 1024.9397917 99009 C67H124O6 TG(20:1(11Z)/22:1(11Z)/22:1(11Z))[iso3]
# ...
